# %%
# 10to put order in ascending and descending order
numbers=[10,20,30]
for i in range(5):
    num=int(input("Enter value:"))
    numbers.append(num)
print("\nOrignal List:",numbers)
#a) ascending order using sorted()
ascending=sorted(numbers)
print("\nthe ascending order is:",ascending)
#b) descending order
numbers.sort(reverse=True)
print("\nthe descending order is:",descending)
#c)length of list
print("the lenght of list is:",len(numbers))
# Out:
# Enter value: 50
# Enter value: 60
# Enter value: 70
# Enter value: 80
# Enter value: 90
# Orignal List: [10, 20, 30, 50, 60, 70, 80, 90]
#
# the ascending order is: [10, 20, 30, 50, 60, 70, 80, 90]
#
# the descending order is: [10, 20, 30, 40, 50, 60, 70, 80]
# the lenght of list is: 8

# %%
#11 to make and acronym froma phrase
phrase=input("enter a phrase:")
words=phrase.split()
acronym=""
for words in words:
    acronym=acronym+words[0]
print("acronym:",acronym.upper())
# Out:
# enter a phrase: be good
# acronym: BG

# %%
# to remove what is duplicated
a=[1,2,3,3,3,4]
u=list(set(a))
print(u)
# Out:
# [1, 2, 3, 4]

# %%
#list
a=[3,4,5,6,7,8,9]
a.append(2)
a.remove(4)
remove_item=a.pop(0)
del a[2]
del a[1-2]

print("the list is",a)
# Out:
# the list is [5, 6, 8, 9]

# %%
#Month abbreviation
months=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
month_number=int(input("Enter month number(1-12):"))
if month_number>=1 and month_number<=12:
    print("Month Abbreviation:",months[month_number-1])
else:
    print("INVALID MONTH NUMBER")
# Out:
# Enter month number(1-12): 3
# Month Abbreviation: Mar

# %%
list1=[10,20,30,40,50]
list2=[30,40,50,60,70]
common=[]
for element in list1:
    if element in list2:
        common.append(element)
print("list1:",list1)
print("list2:",list2)
print("common elements:",common)
# Out:
# list1: [10, 20, 30, 40, 50]
# list2: [30, 40, 50, 60, 70]
# common elements: [30, 40, 50]

# %%
#1program to print 4th from first and 4th from last in the tuple
numbers=[10,20,30,40,50,60,70,80,90]
print("Tuple:",numbers)
print("4th element from first:",numbers[3])
print("4th element from last:",numbers[-4])
# Out:
# Tuple: [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 4th element from first: 40
# 4th element from last: 60

# %%
#2write program to check if element exists in tuple
numbers=(10,20,30,40,50)
element=int(input("Enter element to search:"))
if element in numbers:
    print("element exists in tuple")
else:
    print("element doesnt exist in tuple")
# Out:
# Enter element to search: 30
# element exists in tuple

# %%
#3to convert list to tuple
num_list=[10,20,30,40,50]
num_tuple=tuple(num_list)
print("list:",num_list)
print("tuple:",num_tuple)
# Out:
# list: [10, 20, 30, 40, 50]
# tuple: (10, 20, 30, 40, 50)

# %%
#4index in tuple
num=(10,20,30,40,50)
element=int(input("enter element:"))
if element in num:
    print("index of element:",num.index(element))
else:
    print("element not found")
# Out:
# enter element: 55
# element not found

# %%
#5to replace the last values in the tuple inside the list
numbers=[(10,20,40),(40,59,60),(70,80,90)]
new_list=[]
for tup in numbers:
    new_tup=tup[:-1]+(100,)
    new_list.append(new_tup)
print("orignal list:",numbers)
print("updated list:",new_list)
# Out:
# orignal list: [(10, 20, 40), (40, 59, 60), (70, 80, 90)]
# updated list: [(10, 20, 100), (40, 59, 100), (70, 80, 100)]

# %%
#6 to find max and min element in tuple
numbers=(10,25,30,44,50,)
maximum=max(numbers)
minimum=min(numbers)
print("tuple:",numbers)
print("maximum element:",maximum)
print("minimum element:",minimum)
# Out:
# tuple: (10, 25, 30, 44, 50)
# maximum element: 50
# minimum element: 10

# %%
#7 program to swap first and last element in the tuple
numbers=(10,20,30,40,50)
new_tuple = (numbers[-1],) + numbers[1:-1] + (numbers[0],)
print("orignal tuple:",numbers)
print("tuple after swaping:",new_tuple)
# Out:
# orignal tuple: (10, 20, 30, 40, 50)
# tuple after swaping: (50, 20, 30, 40, 10)

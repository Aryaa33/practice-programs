# %%
#11 dictionary used sorted() function
my_dict = {"name":"ABC",
           "panel":"B",
           "rollno":34,
           "marks":[65,87,67,94]
          }
sorted_dict=sorted(my_dict)
print("sorted keys:",sorted_dict)
# Out:
# sorted keys: ['marks', 'name', 'panel', 'rollno']

# %%
#12 dictionary of 5 students with their marks
students = {
    "vedanshi":99,
    "aryaa":98,
    "aditya":40,
    "Yabi":67,
    "jonny":88
    
}
highest_student=max(students,key=students.get)
print("Student with highest marks:",highest_student)
print("highest marks:",students[highest_student])
# Out:
# Student with highest marks: vedanshi
# highest marks: 99

# %%
#13 to check frequency of each element in a list
numbers=[10,10,20,40,50,40,30,90]
frequency={}
for num in numbers:
    if num in frequency:
        frequency[num]=frequency[num]+1
    else:
        frequency[num]=1
print("frequency of element:",frequency)
# Out:
# frequency of element: {10: 2, 20: 1, 40: 2, 50: 1, 30: 1, 90: 1}

# %%
#14 to sort dictionary values
my_dict={
    "vedanshi":99,
    "aryaa":98,
    "aditya":40,
    "Yabi":67,
    "jonny":88
}
sorted_dict=dict(sorted(my_dict.items(),key=lambda item:item[1]))
print("dictionary sorted by values:",sorted_dict)
# Out:
# dictionary sorted by values: {'aditya': 40, 'Yabi': 67, 'jonny': 88, 'aryaa': 98, 'vedanshi': 99}

# %%
my_dict={
    "vedanshi":99,
    "aryaa":98,
    "aditya":40,
    "Yabi":67,
    "jonny":88
}
sorted_dict=dict(sorted(my_dict.items(),key=lambda item:item[1],revers))
print("dictionary sorted by values:",sorted_dict)
